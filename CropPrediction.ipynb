# %% [markdown]
# ##Crop Prediction ML Model
# **By using RandomForestClassifier Algorithm**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
Data=pd.read_csv('data/Crop_recommendation.csv')

# %%
Data

# %%
Data.head()

# %%
Data.iloc[9] # Displays the entire 10th row of the DataFrame

# %%
Data.tail()

# %%
Data.shape

# %%
Data.isnull().sum()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numerical_cols = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(3, 3, i + 1) # Arrange plots in a 3x3 grid
    sns.histplot(Data[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
x = Data.iloc[:,: -1] # Gets all columns except the last one (features)
y = Data.iloc[:, -1]  # Gets only the last column (target variable, 'label')

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train.head()

# %%
X_test.tail()

# %%
y_train.head()

# %%
y_test.head()

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# %%
prediction=model.predict(X_test)

# %%
accuracy=model.score(X_test,y_test)

# %%
print("accuracy is : ",accuracy)

# %%
new_feature=[[36,58,25,28.66024,59.31891,8.399136,36.9263]]
predicted_crop=model.predict(new_feature)
print("Predicted crop is : ",predicted_crop)

# %%
# Display classification report
print('\nClassification Report:')
print(classification_report(y_test, y_pred))

# %%
# Display confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(15, 12))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=model.classes_, yticklabels=model.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
